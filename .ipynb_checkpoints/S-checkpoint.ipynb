# %%
import socketserver
import json
import uuid

from multiprocessing import Pool
import time


class RPCServer(socketserver.BaseRequestHandler):
    def real_solve(self, req):
        if not hasattr(self, req["functionName"]):
            msg = json.dumps({
                "type": "response",
                "result": "illegal function"
            })
            self.request.sendall(msg.encode("utf-8"))
        else:
            result = str(getattr(self, req["functionName"])(req["parameters"]))

            msg = json.dumps({"type": "response", "result": result})
            self.request.sendall(msg.encode("utf-8"))

        print("thread over")

    def handle(self):

        print("conn is :", self.request)  # conn
        print("addr is :", self.client_address)  # addr
        pool = Pool(5)

        while True:
            try:
                #收消息
                print("new ready")
                data = self.request.recv(1024)
                if not data: break
                print("收到客户端的消息是", data.decode("utf-8"))
                req = json.loads(data.decode("utf-8"))
                pool.apply_async(self.real_solve, [
                    req,
                ])
                print("process start")
            except Exception as e:
                print(e)
                break


class MyServer(RPCServer):
    def add(self, parameters):
        time.sleep(10)
        result = 0
        for i in range(len(parameters)):
            result = result + parameters[i]
        return result


if __name__ == "__main__":
    ip_port = ("127.0.0.1", 8000)
    s = socketserver.ThreadingTCPServer(ip_port, MyServer)
    s.serve_forever()
# Out:
# conn is : <socket.socket fd=59, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 8000), raddr=('127.0.0.1', 50433)>
# addr is : ('127.0.0.1', 50433)
# new ready
# 收到客户端的消息是 {"type": "request", "async": true, "functionName": "add", "parameters": [1, 2]}
# process start
# new ready
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-4:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/yangtao/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-aaf50281a442> in <module>
#      57     ip_port = ("127.0.0.1", 8000)
#      58     s = socketserver.ThreadingTCPServer(ip_port, MyServer)
# ---> 59     s.serve_forever()
#
# ~/anaconda3/lib/python3.7/socketserver.py in serve_forever(self, poll_interval)
#     230
#     231                 while not self.__shutdown_request:
# --> 232                     ready = selector.select(poll_interval)
#     233                     # bpo-35017: shutdown() called during select(), exit immediately.
#     234                     if self.__shutdown_request:
#
# ~/anaconda3/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
